# %%
import numpy as np
import SDOptimizer as SDOmodule
from SDOptimizer.SDOptimizer import SDOptimizer
import matplotlib as plt

# %%
SDO = SDOptimizer()

# %%
X_BOUNDS = [0, 8]
Y_BOUNDS = [-3, 0]
CENTERS = [2,-1.5, 4, -3, 7, 0.5]
example1 = SDO.example_time_to_alarm(X_BOUNDS, Y_BOUNDS, CENTERS[:2], show=True) 
example2 = SDO.example_time_to_alarm(X_BOUNDS, Y_BOUNDS, CENTERS[2:4], show=True) 
example3 = SDO.example_time_to_alarm(X_BOUNDS, Y_BOUNDS, CENTERS[4:], show=True) # show
example_sources = [example1, example2, example3]
bounds =  [Y_BOUNDS[0], X_BOUNDS[0], Y_BOUNDS[1], X_BOUNDS[1]]
NOISE_SCALE = 3
initialization = CENTERS + np.random.normal(scale=NOISE_SCALE, size=(len(CENTERS)))
print(initialization)
# Out:
# [ 6.364332   -5.33647564 -1.20683661 -3.36069141 12.23331444 -1.63935757]

# %%
description = SDO.optimize(example_sources, 1, genetic=True)
# Out:
# The bounds are now [(0.0, 8.0), (-3.0, 0.0)]
# The locations are: (4.645, -0.681),

# %%
description = SDO.optimize(example_sources, 2, genetic=True)
# Out:
# The bounds are now [(0.0, 8.0), (-3.0, 0.0), (0.0, 8.0), (-3.0, 0.0)]
# The locations are: (7.646, -0.081), (2.959, -2.340),

# %%
description = SDO.optimize(example_sources, 3, genetic=True)
# Out:
# The bounds are now [(0.0, 8.0), (-3.0, 0.0), (0.0, 8.0), (-3.0, 0.0), (0.0, 8.0), (-3.0, 0.0)]
# The locations are: (2.211, -1.223), (6.957, -0.006), (4.412, -2.729),

# %% [markdown]
# Here is the gradient-based approach which does not work very well. This needs to be further validated.

# %%
description = SDO.optimize(example_sources, 3, bounds=bounds, initialization=initialization)
print("the result of the optimization is:\n {}".format(description))
# Out:
# The bounds are now [(-3, 0), (0, 8), (-3, 0), (0, 8), (-3, 0), (0, 8)]
# The locations are: (-0.409, 7.818), (-0.100, 1.422), (-2.825, 1.959),
# the result of the optimization is:
#       fun: 49.24999999999999
#  message: 'Optimization terminated successfully.'
#     nfev: 187
#      nit: 1
#  success: True
#     vals: [49.24999999999999]
#        x: array([-0.4090643 ,  7.8180813 , -0.1001012 ,  1.42231085, -2.82524043,
#         1.95925042])
